# %%
import pandas as pd
import pyarrow

# %%
df = pd.read_parquet("data/sia_datasus.parquet", engine="pyarrow", columns=["PA_QTDAPR", "PA_QTDPRO", "PA_VALAPR", "PA_VALPRO", "PA_UFMUN", "PA_MUNPCN", 
                                                                            "PA_MVM", "PA_RACACOR", "PA_IDADE", "PA_CODUNI", "PA_CBOCOD", "PA_PROC_ID"])
df.head()
# Out:
#      PA_QTDAPR    PA_QTDPRO             PA_VALAPR             PA_VALPRO  \
# 0            1            1                  4.11                  4.11
# 1            1            1                  4.11                  4.11
# 2            1            1                  0.00                  0.00
# 3            1            1                  1.85                  1.85
# 4            1            1                  0.00                  0.00
#
#   PA_UFMUN PA_MUNPCN  PA_MVM PA_RACACOR PA_IDADE PA_CODUNI PA_CBOCOD  \
# 0   250750    250750  202601         03      024   2707519    223415
# 1   250750    250750  202601         03      028   2399717    221205
# 2   250630    250080  202601         03      030   2603802    223505
# 3   250400    250400  202601         03      052   2363135    223415
# 4   250750    250750  202601         03      030   0806846    223208
#
#    PA_PROC_ID
# 0  0202020380
# 1  0202020380
# 2  0301060118
# 3  0202010295
# 4  0101020104

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1506891 entries, 0 to 1506890
# Data columns (total 12 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   PA_QTDAPR   1506891 non-null  string
#  1   PA_QTDPRO   1506891 non-null  string
#  2   PA_VALAPR   1506891 non-null  string
#  3   PA_VALPRO   1506891 non-null  string
#  4   PA_UFMUN    1506891 non-null  string
#  5   PA_MUNPCN   1506891 non-null  string
#  6   PA_MVM      1506891 non-null  string
#  7   PA_RACACOR  1506891 non-null  string
#  8   PA_IDADE    1506891 non-null  string
#  9   PA_CODUNI   1506891 non-null  string
#  10  PA_CBOCOD   1506891 non-null  string
#  11  PA_PROC_ID  1506891 non-null  string
# dtypes: string(12)
# memory usage: 138.0 MB
